# %% [markdown]
# # Preparación del Dataset
# ---
#
# - Se obtienen y preprocesan textos directos del dataset para luego ser persistidos.

# %%
import pandas as pd
import os
from document import Document
import util.log as log
from multiprocessing import Process
from multiprocessing import Manager
from multiprocessing import Pool
import pandas as pd
from datetime import datetime

# %%
corpora = []
init_time = datetime.now()
directory = '../labeled_dataset/'
files = os.listdir(directory)
dataframe = None
number_of_cores_to_use = 10

def process_file(file):
    log.info('Processing file: {}'.format(file))
    try:
        path = '{}{}'.format(directory, file)
        document = Document(path = path)
        splitted_file = file.split(' $ ') 
        topic = splitted_file[0]
        title = splitted_file[1]
        return [path, title, document.string, document.word_count(), document.type_count(), document.sentences,\
                       document.lemmatized_string, document.stemmed_string, document.simple_preprocessed_string, topic, \
                       document.named_entities, document.bigrams, document.trigrams, document.lemmatized_bigrams, \
                       document.lemmatized_trigrams, document.stemmed_bigrams, document.stemmed_trigrams, \
                       document.simple_preprocessed_bigrams, document.simple_preprocessed_trigrams, document.preprocessed_sentences,
                       document.paragraphs, document.preprocessed_paragraphs]
    except InvalidDocument:
        pass



with Pool(number_of_cores_to_use) as pool:
    corpora = pool.map(process_file, files)

time = datetime.now() - init_time
log.info('{} documents were processed. {} documents errored. Total time used: {}, Total cores used: {}'.format(len(corpora), corpora.count([]), \
                                                                                                          str(time), number_of_cores_to_use))

# %%
dataframe = pd.DataFrame(data = corpora, columns=['original_path', 'document_title', 'string', 'word_count', 'type_count', 'sentences','lemmatized_text', 'stemmed_text', 'simple_preprocessed', 'topic', 'named_entities', 'tokens_bigrams', 'tokens_trigrams', 'lemmatized_bigrams', 'lemmatized_trigrams', 'stemmed_bigrams', 'stemmed_trigrams', 'simple_preprocessed_bigrams', 'simple_preprocessed_trigrams', 'preprocessed_sentences', 'paragraphs', 'preprocessed_paragraphs'])

# %%
dataframe.to_csv('data.csv')

# %%
dataframe
# Out:
#                                          original_path  \
# 0    ../labeled_dataset/La larga cola $ TP2 - La La...
# 1    ../labeled_dataset/Sistemas emergentes $ TP_6_...
# 2    ../labeled_dataset/La sociedad de costo margin...
# 3    ../labeled_dataset/Wikinomics $ TP1-Franco Zan...
# 4    ../labeled_dataset/Economia de experiencia $ T...
# ..                                                 ...
# 301  ../labeled_dataset/La sociedad de costo margin...
# 302  ../labeled_dataset/La sociedad de costo margin...
# 303  ../labeled_dataset/Sistemas emergentes $ TP6  ...
# 304  ../labeled_dataset/Economia de experiencia $ T...
# 305  ../labeled_dataset/Wikinomics $ TP 4 - Wikinom...
#
#                                         document_title  \
# 0    TP2 - La Larga Cola de Chris Anderson corto - ...
# 1                               TP_6_Weiss_Gonzalo.pdf
# 2    TP N° 5 – La sociedad de costo marginal cero -...
# 3                              TP1-Franco Zanette.docx
# 4                                        TP 3 (1).docx
# ..                                                 ...
# 301                                  TP5-Gariglio.docx
# 302  TP5 - La sociedad de MG Cero - Rifkin - Santia...
# 303     TP6  - Sistemas emergentes - Joel Melamed.docx
# 304  TP 3 - Economía de Experiencia - Andrés Basso ...
# 305                              TP 4 - Wikinomía.docx
#
#                                                 string  word_count  \
# 0     Universidad Tecnológica Nacional Facultad Reg...        1234
# 1    TRABAJO PRÁCTICO N°6 Curso: K5052 Profesor: Al...         480
# 2    MARKETING EN INTERNET Y NUEVA ECONOMÍA Cátedra...        1031
# 3    Alumno: Franco Zanette (147. 074-7)Institución...        1180
# 4    TP 3¿Qué 3 elementos hacen resurgir con fuerza...         590
# ..                                                 ...         ...
# 301  PREGUNTAS TP5 - (Test de lectura sobre capítul...         698
# 302  curso: K5071 - 2 Cuat. 2016Marketing en Intern...         745
# 303  MarketingProfesor: Alejandro Prince, Hernan Bo...         434
# 304  The experience economy - Joseph PINE II y Jame...         771
# 305  Marketing en Internet y Nueva EconomíaTrabajo ...        2053
#
#      type_count                                          sentences  \
# 0           477  [ Universidad Tecnológica Nacional Facultad Re...
# 1           231  [TRABAJO PRÁCTICO N°6 Curso: K5052 Profesor: A...
# 2           444  [MARKETING EN INTERNET Y NUEVA ECONOMÍA Cátedr...
# 3           472  [Alumno: Franco Zanette (147., 074-7)Instituci...
# 4           309  [TP 3¿Qué 3 elementos hacen resurgir con fuerz...
# ..          ...                                                ...
# 301         330  [PREGUNTAS TP5 - (Test de lectura sobre capítu...
# 302         336  [curso: K5071 - 2 Cuat., 2016Marketing en Inte...
# 303         222  [MarketingProfesor: Alejandro Prince, Hernan B...
# 304         380  [The experience economy - Joseph PINE II y Jam...
# 305         736  [Marketing en Internet y Nueva EconomíaTrabajo...
#
#                                        lemmatized_text  \
# 0    [sistema, curso, cuat, marketing, nuevo, dr, a...
# 1    [trabajo, curso, fecha, entregar, nombre, apel...
# 2    [marketing, nuevo, ayudante, maximiliano, brac...
# 3    [tp, fecha, concepto, concepto, hacer, referen...
# 4    [tp, elemento, hacer, resurgir, fuerza, idea, ...
# ..                                                 ...
# 301  [pregunta, lectura, sociedad, costo, marginal,...
# 302  [curso, cuat, nuevo, dr, princeayudante, traba...
# 303  [marketingprofesor, entregar, trabajo, sistema...
# 304  [experience, ii, gilmorepreguntas, trabajo, re...
# 305  [marketing, nuevo, princeayudante, borrecurso,...
#
#                                           stemmed_text  \
# 0    [cuat, marketing, nuev, dr, ayud, trabaj, col,...
# 1    [trabaj, nombr, email, gmail, com, marketing, ...
# 2    [marketing, nuev, ayud, trabaj, tp, socied, co...
# 3    [tp, form, masiv, riquez, sector, context, emp...
# 4    [tp, ide, pod, facilit, ser, prosper, nuev, de...
# ..                                                 ...
# 301  [pregunt, lectur, socied, cost, marginal, cer,...
# 302  [cuat, nuev, dr, princeayud, trabaj, socied, c...
# 303  [marketingprofesor, trabaj, central, particul,...
# 304  [ii, trabaj, lectur, ide, defin, caracteriz, p...
# 305  [marketing, nuev, princeayud, enunci, ide, dar...
#
#                                    simple_preprocessed  \
# 0    [sistemas, curso, cuat, marketing, nueva, dr, ...
# 1    [trabajo, curso, fecha, entrega, nombre, apell...
# 2    [marketing, nueva, ayudantes, maximiliano, bra...
# 3    [tp, fecha, concepto, concepto, hace, referenc...
# 4    [tp, elementos, hacen, resurgir, fuerza, idea,...
# ..                                                 ...
# 301  [preguntas, lectura, sociedad, costo, marginal...
# 302  [curso, cuat, nueva, dr, princeayudante, traba...
# 303  [marketingprofesor, entrega, trabajo, sistemas...
# 304  [experience, ii, gilmorepreguntas, trabajo, re...
# 305  [marketing, nueva, princeayudante, borrecurso,...
#
#                                   topic  ...  \
# 0                         La larga cola  ...
# 1                   Sistemas emergentes  ...
# 2    La sociedad de costo marginal cero  ...
# 3                            Wikinomics  ...
# 4               Economia de experiencia  ...
# ..                                  ...  ...
# 301  La sociedad de costo marginal cero  ...
# 302  La sociedad de costo marginal cero  ...
# 303                 Sistemas emergentes  ...
# 304             Economia de experiencia  ...
# 305                          Wikinomics  ...
#
#                                        tokens_trigrams  \
# 0    [(Universidad, Tecnológica, Nacional), (Tecnol...
# 1    [(TRABAJO, PRÁCTICO, N°6), (PRÁCTICO, N°6, Cur...
# 2    [(MARKETING, EN, INTERNET), (EN, INTERNET, Y),...
# 3    [(Alumno, :, Franco), (:, Franco, Zanette), (F...
# 4    [(TP, 3¿Qué, 3), (3¿Qué, 3, elementos), (3, el...
# ..                                                 ...
# 301  [(PREGUNTAS, TP5, -), (TP5, -, (), (-, (, Test...
# 302  [(curso, :, K5071), (:, K5071, -), (K5071, -, ...
# 303  [(MarketingProfesor, :, Alejandro), (:, Alejan...
# 304  [(The, experience, economy), (experience, econ...
# 305  [(Marketing, en, Internet), (en, Internet, y),...
#
#                                     lemmatized_bigrams  \
# 0    [(sistema, curso), (curso, cuat), (cuat, marke...
# 1    [(trabajo, curso), (curso, fecha), (fecha, ent...
# 2    [(marketing, nuevo), (nuevo, ayudante), (ayuda...
# 3    [(tp, fecha), (fecha, concepto), (concepto, co...
# 4    [(tp, elemento), (elemento, hacer), (hacer, re...
# ..                                                 ...
# 301  [(pregunta, lectura), (lectura, sociedad), (so...
# 302  [(curso, cuat), (cuat, nuevo), (nuevo, dr), (d...
# 303  [(marketingprofesor, entregar), (entregar, tra...
# 304  [(experience, ii), (ii, gilmorepreguntas), (gi...
# 305  [(marketing, nuevo), (nuevo, princeayudante), ...
#
#                                    lemmatized_trigrams  \
# 0    [(sistema, curso, cuat), (curso, cuat, marketi...
# 1    [(trabajo, curso, fecha), (curso, fecha, entre...
# 2    [(marketing, nuevo, ayudante), (nuevo, ayudant...
# 3    [(tp, fecha, concepto), (fecha, concepto, conc...
# 4    [(tp, elemento, hacer), (elemento, hacer, resu...
# ..                                                 ...
# 301  [(pregunta, lectura, sociedad), (lectura, soci...
# 302  [(curso, cuat, nuevo), (cuat, nuevo, dr), (nue...
# 303  [(marketingprofesor, entregar, trabajo), (entr...
# 304  [(experience, ii, gilmorepreguntas), (ii, gilm...
# 305  [(marketing, nuevo, princeayudante), (nuevo, p...
#
#                                        stemmed_bigrams  \
# 0    [(cuat, marketing), (marketing, nuev), (nuev, ...
# 1    [(trabaj, nombr), (nombr, email), (email, gmai...
# 2    [(marketing, nuev), (nuev, ayud), (ayud, traba...
# 3    [(tp, form), (form, masiv), (masiv, riquez), (...
# 4    [(tp, ide), (ide, pod), (pod, facilit), (facil...
# ..                                                 ...
# 301  [(pregunt, lectur), (lectur, socied), (socied,...
# 302  [(cuat, nuev), (nuev, dr), (dr, princeayud), (...
# 303  [(marketingprofesor, trabaj), (trabaj, central...
# 304  [(ii, trabaj), (trabaj, lectur), (lectur, ide)...
# 305  [(marketing, nuev), (nuev, princeayud), (princ...
#
#                                       stemmed_trigrams  \
# 0    [(cuat, marketing, nuev), (marketing, nuev, dr...
# 1    [(trabaj, nombr, email), (nombr, email, gmail)...
# 2    [(marketing, nuev, ayud), (nuev, ayud, trabaj)...
# 3    [(tp, form, masiv), (form, masiv, riquez), (ma...
# 4    [(tp, ide, pod), (ide, pod, facilit), (pod, fa...
# ..                                                 ...
# 301  [(pregunt, lectur, socied), (lectur, socied, c...
# 302  [(cuat, nuev, dr), (nuev, dr, princeayud), (dr...
# 303  [(marketingprofesor, trabaj, central), (trabaj...
# 304  [(ii, trabaj, lectur), (trabaj, lectur, ide), ...
# 305  [(marketing, nuev, princeayud), (nuev, princea...
#
#                            simple_preprocessed_bigrams  \
# 0    [(sistemas, curso), (curso, cuat), (cuat, mark...
# 1    [(trabajo, curso), (curso, fecha), (fecha, ent...
# 2    [(marketing, nueva), (nueva, ayudantes), (ayud...
# 3    [(tp, fecha), (fecha, concepto), (concepto, co...
# 4    [(tp, elementos), (elementos, hacen), (hacen, ...
# ..                                                 ...
# 301  [(preguntas, lectura), (lectura, sociedad), (s...
# 302  [(curso, cuat), (cuat, nueva), (nueva, dr), (d...
# 303  [(marketingprofesor, entrega), (entrega, traba...
# 304  [(experience, ii), (ii, gilmorepreguntas), (gi...
# 305  [(marketing, nueva), (nueva, princeayudante), ...
#
#                           simple_preprocessed_trigrams  \
# 0    [(sistemas, curso, cuat), (curso, cuat, market...
# 1    [(trabajo, curso, fecha), (curso, fecha, entre...
# 2    [(marketing, nueva, ayudantes), (nueva, ayudan...
# 3    [(tp, fecha, concepto), (fecha, concepto, conc...
# 4    [(tp, elementos, hacen), (elementos, hacen, re...
# ..                                                 ...
# 301  [(preguntas, lectura, sociedad), (lectura, soc...
# 302  [(curso, cuat, nueva), (cuat, nueva, dr), (nue...
# 303  [(marketingprofesor, entrega, trabajo), (entre...
# 304  [(experience, ii, gilmorepreguntas), (ii, gilm...
# 305  [(marketing, nueva, princeayudante), (nueva, p...
#
#                                 preprocessed_sentences  \
# 0    [marketing nuevo dr ayudante, trabajo largo co...
# 1    [trabajo curso fecha entregar nombre apellido ...
# 2    [marketing nuevo ayudante maximiliano bracho t...
# 3    [concepto hacer referencia gente forma masivo ...
# 4    [tp elemento hacer resurgir fuerza idea experi...
# ..                                                 ...
# 301  [pregunta lectura sociedad costo marginal cero...
# 302  [trabajo sociedad costo marginal ceroalumno pe...
# 303  [marketingprofesor entregar trabajo sistema pr...
# 304  [experience ii gilmorepreguntas trabajo requer...
# 305  [marketing nuevo princeayudante borrecurso cua...
#
#                                             paragraphs  \
# 0    [ Universidad Tecnológica Nacional Facultad Re...
# 1    [TRABAJO PRÁCTICO N°6 Curso: K5052 Profesor: A...
# 2    [MARKETING EN INTERNET Y NUEVA ECONOMÍA Cátedr...
# 3    [Alumno: Franco Zanette (147.074-7), Instituci...
# 4    [TP 3, ¿Qué 3 elementos hacen resurgir con fue...
# ..                                                 ...
# 301  [PREGUNTAS TP5 - (Test de lectura sobre capítu...
# 302  [curso: K5071 - 2 Cuat. 2016, Marketing en Int...
# 303  [, , Marketing, Profesor: Alejandro Prince, He...
# 304  [The experience economy - Joseph PINE II y Jam...
# 305  [, Marketing en Internet y Nueva Economía, Tra...
#
#                                preprocessed_paragraphs
# 0    [sistema curso cuat marketing nuevo dr ayudant...
# 1    [trabajo curso fecha entregar nombre apellido ...
# 2    [marketing nuevo ayudante maximiliano bracho t...
# 3    [, frba, tp tp, fecha, , concepto, , concepto ...
# 4    [tp, elemento hacer resurgir fuerza idea exper...
# ..                                                 ...
# 301  [pregunta lectura, , sociedad costo marginal c...
# 302  [curso cuat, marketing nuevo, , dr, , ayudante...
# 303  [, , marketing, , trabajo, , , , fecha entrega...
# 304  [experience ii, pregunta trabajo, nota requeri...
# 305  [, marketing nuevo, trabajo, , , , ayudante, c...
#
# [306 rows x 22 columns]
