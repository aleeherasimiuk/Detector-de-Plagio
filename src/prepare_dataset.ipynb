# %% [markdown]
# # Preparación del Dataset
# ---
#
# - Se obtienen y preprocesan textos directos del dataset para luego ser persistidos.

# %%
import pandas as pd
import os
from document import Document
import util.log as log
from multiprocessing import Process
from multiprocessing import Manager
from multiprocessing import Pool
import pandas as pd
from datetime import datetime
log.init_logger()
from util.exceptions import InvalidDocument

# %%
preprocess_list = ['lemmatized_string', 'sentences', 'preprocessed_sentences', 'paragraphs', 'preprocessed_paragraphs', 'named_entities', 'urls']

# %%
def process_file(file):
    log.info('Processing file: {}'.format(file))
    try:
        path = '{}{}'.format(directory, file)
        document = Document(path = path, preprocess_list = preprocess_list)
        splitted_file = file.split(' $ ') 
        topic = splitted_file[0]
        title = splitted_file[1]
        return [path, title, document.string, document.word_count(), document.type_count(), document.sentences,\
                       document.lemmatized_string, document.stemmed_string, document.simple_preprocessed_string, topic, \
                       document.named_entities, document.bigrams, document.trigrams, document.lemmatized_bigrams, \
                       document.lemmatized_trigrams, document.stemmed_bigrams, document.stemmed_trigrams, \
                       document.simple_preprocessed_bigrams, document.simple_preprocessed_trigrams, document.preprocessed_sentences,
                       document.paragraphs, document.preprocessed_paragraphs, document.urls]
    except InvalidDocument:
        return []

# %%
corpora = []
init_time = datetime.now()
directory = '../labeled_dataset/'
files = os.listdir(directory)
number_of_cores_to_use = 10
dataframe_dataset = None


with Pool(number_of_cores_to_use) as pool:
    corpora = pool.map(process_file, files)

time = datetime.now() - init_time
log.info('{} documents were processed. {} documents errored. Total time used: {}, Total cores used: {}'.format(len(corpora), corpora.count([]), \
                                                                                                          str(time), number_of_cores_to_use))

# %%
dataframe_dataset = pd.DataFrame(data = corpora, columns=['original_path', 'title', 'string', 'word_count', 'type_count', 'sentences','lemmatized_string', 'stemmed_string', 'simple_preprocessed_string', 'topic', 'named_entities', 'tokens_bigrams', 'tokens_trigrams', 'lemmatized_bigrams', 'lemmatized_trigrams', 'stemmed_bigrams', 'stemmed_trigrams', 'simple_preprocessed_bigrams', 'simple_preprocessed_trigrams', 'preprocessed_sentences', 'paragraphs', 'preprocessed_paragraphs', 'urls'])

# %%
dataframe_dataset.to_csv('../data/dataset.csv')

# %%
dataframe_dataset
# Out:
#                                          original_path  \
# 0    ../labeled_dataset/La larga cola $ TP2 - La La...
# 1    ../labeled_dataset/Sistemas emergentes $ TP_6_...
# 2    ../labeled_dataset/La sociedad de costo margin...
# 3    ../labeled_dataset/Wikinomics $ TP1-Franco Zan...
# 4    ../labeled_dataset/Economia de experiencia $ T...
# ..                                                 ...
# 300  ../labeled_dataset/La sociedad de costo margin...
# 301  ../labeled_dataset/La sociedad de costo margin...
# 302  ../labeled_dataset/Sistemas emergentes $ TP6  ...
# 303  ../labeled_dataset/Economia de experiencia $ T...
# 304  ../labeled_dataset/Wikinomics $ TP 4 - Wikinom...
#
#                                                  title  \
# 0    TP2 - La Larga Cola de Chris Anderson corto - ...
# 1                               TP_6_Weiss_Gonzalo.pdf
# 2    TP N° 5 – La sociedad de costo marginal cero -...
# 3                              TP1-Franco Zanette.docx
# 4                                        TP 3 (1).docx
# ..                                                 ...
# 300                                  TP5-Gariglio.docx
# 301  TP5 - La sociedad de MG Cero - Rifkin - Santia...
# 302     TP6  - Sistemas emergentes - Joel Melamed.docx
# 303  TP 3 - Economía de Experiencia - Andrés Basso ...
# 304                              TP 4 - Wikinomía.docx
#
#                                                 string  word_count  \
# 0     Universidad Tecnológica Nacional Facultad Reg...        1234
# 1    TRABAJO PRÁCTICO N°6 Curso: K5052 Profesor: Al...         480
# 2    MARKETING EN INTERNET Y NUEVA ECONOMÍA Cátedra...        1031
# 3    Alumno: Franco Zanette (147. 074-7)Institución...        1180
# 4    TP 3¿Qué 3 elementos hacen resurgir con fuerza...         590
# ..                                                 ...         ...
# 300  PREGUNTAS TP5 - (Test de lectura sobre capítul...         698
# 301  curso: K5071 - 2 Cuat. 2016Marketing en Intern...         745
# 302  MarketingProfesor: Alejandro Prince, Hernan Bo...         434
# 303  The experience economy - Joseph PINE II y Jame...         771
# 304  Marketing en Internet y Nueva EconomíaTrabajo ...        2053
#
#      type_count                                          sentences  \
# 0           477  [ Universidad Tecnológica Nacional Facultad Re...
# 1           231  [TRABAJO PRÁCTICO N°6 Curso: K5052 Profesor: A...
# 2           444  [MARKETING EN INTERNET Y NUEVA ECONOMÍA Cátedr...
# 3           472  [Alumno: Franco Zanette (147., 074-7)Instituci...
# 4           309  [TP 3¿Qué 3 elementos hacen resurgir con fuerz...
# ..          ...                                                ...
# 300         330  [PREGUNTAS TP5 - (Test de lectura sobre capítu...
# 301         336  [curso: K5071 - 2 Cuat., 2016Marketing en Inte...
# 302         222  [MarketingProfesor: Alejandro Prince, Hernan B...
# 303         380  [The experience economy - Joseph PINE II y Jam...
# 304         736  [Marketing en Internet y Nueva EconomíaTrabajo...
#
#                                      lemmatized_string stemmed_string  \
# 0    [sistema, curso, cuat, marketing, nuevo, dr, a...           None
# 1    [trabajo, curso, fecha, entregar, nombre, apel...           None
# 2    [marketing, nuevo, ayudante, maximiliano, brac...           None
# 3    [tp, fecha, concepto, concepto, hacer, referen...           None
# 4    [tp, elemento, hacer, resurgir, fuerza, idea, ...           None
# ..                                                 ...            ...
# 300  [pregunta, lectura, sociedad, costo, marginal,...           None
# 301  [curso, cuat, nuevo, dr, princeayudante, traba...           None
# 302  [marketingprofesor, entregar, trabajo, sistema...           None
# 303  [experience, ii, gilmorepreguntas, trabajo, re...           None
# 304  [marketing, nuevo, princeayudante, borrecurso,...           None
#
#     simple_preprocessed_string                               topic  ...  \
# 0                         None                       La larga cola  ...
# 1                         None                 Sistemas emergentes  ...
# 2                         None  La sociedad de costo marginal cero  ...
# 3                         None                          Wikinomics  ...
# 4                         None             Economia de experiencia  ...
# ..                         ...                                 ...  ...
# 300                       None  La sociedad de costo marginal cero  ...
# 301                       None  La sociedad de costo marginal cero  ...
# 302                       None                 Sistemas emergentes  ...
# 303                       None             Economia de experiencia  ...
# 304                       None                          Wikinomics  ...
#
#     lemmatized_bigrams lemmatized_trigrams stemmed_bigrams stemmed_trigrams  \
# 0                 None                None            None             None
# 1                 None                None            None             None
# 2                 None                None            None             None
# 3                 None                None            None             None
# 4                 None                None            None             None
# ..                 ...                 ...             ...              ...
# 300               None                None            None             None
# 301               None                None            None             None
# 302               None                None            None             None
# 303               None                None            None             None
# 304               None                None            None             None
#
#     simple_preprocessed_bigrams simple_preprocessed_trigrams  \
# 0                          None                         None
# 1                          None                         None
# 2                          None                         None
# 3                          None                         None
# 4                          None                         None
# ..                          ...                          ...
# 300                        None                         None
# 301                        None                         None
# 302                        None                         None
# 303                        None                         None
# 304                        None                         None
#
#                                 preprocessed_sentences  \
# 0    [sistema curso cuat, marketing nuevo dr ayudan...
# 1    [trabajo curso fecha entregar nombre apellido ...
# 2    [marketing nuevo ayudante maximiliano bracho t...
# 3    [, tp fecha, concepto, concepto hacer referenc...
# 4    [tp elemento hacer resurgir fuerza idea experi...
# ..                                                 ...
# 300  [pregunta lectura sociedad costo marginal cero...
# 301  [curso cuat, nuevo dr princeayudante, trabajo ...
# 302  [marketingprofesor entregar trabajo sistema pr...
# 303  [experience ii gilmorepreguntas trabajo requer...
# 304  [marketing nuevo princeayudante borrecurso cua...
#
#                                             paragraphs  \
# 0    [ Universidad Tecnológica Nacional Facultad Re...
# 1    [TRABAJO PRÁCTICO N°6 Curso: K5052 Profesor: A...
# 2    [MARKETING EN INTERNET Y NUEVA ECONOMÍA Cátedr...
# 3    [Alumno: Franco Zanette (147.074-7), Instituci...
# 4    [TP 3, ¿Qué 3 elementos hacen resurgir con fue...
# ..                                                 ...
# 300  [PREGUNTAS TP5 - (Test de lectura sobre capítu...
# 301  [curso: K5071 - 2 Cuat. 2016, Marketing en Int...
# 302  [, , Marketing, Profesor: Alejandro Prince, He...
# 303  [The experience economy - Joseph PINE II y Jam...
# 304  [, Marketing en Internet y Nueva Economía, Tra...
#
#                                preprocessed_paragraphs urls
# 0    [sistema curso cuat marketing nuevo dr ayudant...   []
# 1    [trabajo curso fecha entregar nombre apellido ...   []
# 2    [marketing nuevo ayudante maximiliano bracho t...   []
# 3    [, frba, tp tp, fecha, , concepto, , concepto ...   []
# 4    [tp, elemento hacer resurgir fuerza idea exper...   []
# ..                                                 ...  ...
# 300  [pregunta lectura, , sociedad costo marginal c...   []
# 301  [curso cuat, marketing nuevo, , dr, , ayudante...   []
# 302  [, , marketing, , trabajo, , , , fecha entrega...   []
# 303  [experience ii, pregunta trabajo, nota requeri...   []
# 304  [, marketing nuevo, trabajo, , , , ayudante, c...   []
#
# [305 rows x 23 columns]

# %% [markdown]
# # Preparado de Libros

# %%
preprocess_list = ['lemmatized_string', 'sentences', 'preprocessed_sentences', 'paragraphs', 'preprocessed_paragraphs']

# %%
def process_book(file):
    log.info('Processing file: {}'.format(file))
    try:
        path = '{}{}'.format(directory, file)
        document = Document(path = path, preprocess_list = preprocess_list)
        splitted_file = file.split(' $ ') 
        topic = splitted_file[0]
        title = splitted_file[1]
        return [path, title, document.string, document.word_count(), document.type_count(), document.sentences,\
                       document.lemmatized_string, document.stemmed_string, document.simple_preprocessed_string, topic, \
                       document.named_entities, document.bigrams, document.trigrams, document.lemmatized_bigrams, \
                       document.lemmatized_trigrams, document.stemmed_bigrams, document.stemmed_trigrams, \
                       document.simple_preprocessed_bigrams, document.simple_preprocessed_trigrams, document.preprocessed_sentences,
                       document.paragraphs, document.preprocessed_paragraphs, document.urls]
    except InvalidDocument:
        return []

# %%
books = []
init_time = datetime.now()
directory = '../books/'
files = os.listdir(directory)
number_of_cores_to_use = 10
dataframe_books = None


with Pool(number_of_cores_to_use) as pool:
    books = pool.map(process_file, files)

time = datetime.now() - init_time
log.info('{} documents were processed. {} documents errored. Total time used: {}, Total cores used: {}'.format(len(books), books.count([]), \
                                                                                                          str(time), number_of_cores_to_use))

# %%
dataframe_books = pd.DataFrame(data = books, columns=['original_path', 'title', 'string', 'word_count', 'type_count', 'sentences','lemmatized_string', 'stemmed_string', 'simple_preprocessed_string', 'topic', 'named_entities', 'bigrams', 'trigrams', 'lemmatized_bigrams', 'lemmatized_trigrams', 'stemmed_bigrams', 'stemmed_trigrams', 'simple_preprocessed_bigrams', 'simple_preprocessed_trigrams', 'preprocessed_sentences', 'paragraphs', 'preprocessed_paragraphs', 'urls'])

# %%
dataframe_books.to_csv('../data/books.csv')

# %%
dataframe_books
# Out:
#                                        original_path  \
# 0  ../books/La nueva economia $ Kotler_P_and_Arms...
# 1  ../books/La sociedad de costo marginal cero $ ...
# 2  ../books/La larga cola $ Chris_Anderson_La_eco...
# 3                ../books/Wikinomics $ Wikinomia.pdf
# 4  ../books/Sistemas Emergentes $ Steven_Johnson_...
#
#                                                title  \
# 0       Kotler_P_and_Armstrong_G_2008_Fundamento.pdf
# 1             la sociedad de costo marginal cero.pdf
# 2  Chris_Anderson_La_economia_Long_Tail_TRUNCATED...
# 3                                      Wikinomia.pdf
# 4  Steven_Johnson_Sistemas_emergentes_O_que_tiene...
#
#                                               string  word_count  type_count  \
# 0  Port. Marketing Kotler 1/24/08 1:31 PM Page 1 ...      479416       31417
# 1  Jeremy Rifkin es uno de los pensadores sociale...        9392        2524
# 2  Chris Anderson La economía Long Tail De los me...       28002        5327
# 3  Wikinom€a 1 Wikinom€a Wikinomics: la nueva eco...        2132         881
# 4  e u r e reseñas libros “Lo que surgió en las c...        1969         760
#
#                                            sentences  \
# 0  [Port., Marketing Kotler 1/24/08 1:31 PM Page ...
# 1  [Jeremy Rifkin es uno de los pensadores social...
# 2  [Chris Anderson La economía Long Tail De los m...
# 3  [Wikinom€a 1 Wikinom€a Wikinomics: la nueva ec...
# 4  [e u r e reseñas libros “Lo que surgió en las ...
#
#                                    lemmatized_string stemmed_string  \
# 0  [marketing, pm, philip, autoridad, marketing, ...           None
# 1  [rifkin, pensador, social, asesor, europeo, di...           None
# 2  [mercado, masa, triunfo, minoritario, tendenci...           None
# 3  [nuevo, econom, multitud, inteligente, tapa, l...           None
# 4  [libro, surgir, calle, modelo, activismo, refl...           None
#
#   simple_preprocessed_string                               topic  ...  \
# 0                       None                   La nueva economia  ...
# 1                       None  La sociedad de costo marginal cero  ...
# 2                       None                       La larga cola  ...
# 3                       None                          Wikinomics  ...
# 4                       None                 Sistemas Emergentes  ...
#
#   lemmatized_bigrams lemmatized_trigrams stemmed_bigrams stemmed_trigrams  \
# 0               None                None            None             None
# 1               None                None            None             None
# 2               None                None            None             None
# 3               None                None            None             None
# 4               None                None            None             None
#
#   simple_preprocessed_bigrams simple_preprocessed_trigrams  \
# 0                        None                         None
# 1                        None                         None
# 2                        None                         None
# 3                        None                         None
# 4                        None                         None
#
#                               preprocessed_sentences  \
# 0  [, marketing pm philip autoridad marketing mun...
# 1  [rifkin pensador social, asesor europeo divers...
# 2  [mercado masa triunfo minoritario tendencia ed...
# 3  [nuevo econom multitud inteligente tapa libro ...
# 4  [libro surgir calle modelo activismo reflejar ...
#
#                                           paragraphs  \
# 0  [Port. Marketing Kotler 1/24/08 1:31 PM Page 1...
# 1  [Jeremy Rifkin es uno de los pensadores social...
# 2  [Chris Anderson La economía Long Tail De los m...
# 3  [Wikinom€a 1 Wikinom€a Wikinomics: la nueva ec...
# 4  [e u r e reseñas libros “Lo que surgió en las ...
#
#                              preprocessed_paragraphs urls
# 0  [marketing pm philip autoridad marketing mundo...   []
# 1  [rifkin pensador social asesor europeo diverso...   []
# 2  [mercado masa triunfo minoritario tendencia ed...   []
# 3  [nuevo econom multitud inteligente tapa libro ...   []
# 4  [libro surgir calle modelo activismo reflejar ...   []
#
# [5 rows x 23 columns]
